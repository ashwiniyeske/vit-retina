jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2657169592.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/4177200098.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/431731696.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1212460226.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2273730548.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2934031861.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/4031880127.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3258193135.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1142830488.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2570980846.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3181273999.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/556665949.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3111934110.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3223282866.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1791690921.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3673046362.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2481096927.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3899993787.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2963468821.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/157784182.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/625250328.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1915044107.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1467290004.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1250343314.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3414625841.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3983529541.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2428477722.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/966788042.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1285588852.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/164643516.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1989483426.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/860415279.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2241498976.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/632357010.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/197942022.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3299560037.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/813688651.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1362265434.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1165503053.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2405559933.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/4056167943.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2282888474.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/3261726496.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/1904073700.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/2647544506.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/952391818.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/train_images/410556634.jpg
# /kaggle/input/c/cassava-leaf-disease-classification/test_images/2216849948.jpg

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import glob, warnings
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

warnings.filterwarnings('ignore')
print('TensorFlow Version ' + tf.__version__)
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# TensorFlow Version 2.12.0

# %%
IMAGE_SIZE = 224
BATCH_SIZE = 16
EPOCHS = 7

TRAIN_PATH = '/kaggle/input/c/cassava-leaf-disease-classification/train_images'
TEST_PATH = '/kaggle/input/c/cassava-leaf-disease-classification/test_images'

DF_TRAIN = pd.read_csv('/kaggle/input/c/cassava-leaf-disease-classification/train.csv', dtype='str')
TEST_IMAGES = glob.glob(TEST_PATH + '/*.jpg')
DF_TEST = pd.DataFrame(TEST_IMAGES, columns = ['image_path'])

classes = {0 : "Cassava Bacterial Blight (CBB)",
           1 : "Cassava Brown Streak Disease (CBSD)",
           2 : "Cassava Green Mottle (CGM)",
           3 : "Cassava Mosaic Disease (CMD)",
           4 : "Healthy"}

# %%
def data_augment(image):
    p_spatial = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_rotate = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_1 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_2 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    p_pixel_3 = tf.random.uniform([], 0, 1.0, dtype = tf.float32)
    
    # Flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    
    if p_spatial > .75:
        image = tf.image.transpose(image)
        
    # Rotates
    if p_rotate > .75:
        image = tf.image.rot90(image, k = 3) # rotate 270º
    elif p_rotate > .5:
        image = tf.image.rot90(image, k = 2) # rotate 180º
    elif p_rotate > .25:
        image = tf.image.rot90(image, k = 1) # rotate 90º

# Pixel-level transforms
    if p_pixel_1 >= .4:
        image = tf.image.random_saturation(image, lower = .7, upper = 1.3)
    if p_pixel_2 >= .4:
        image = tf.image.random_contrast(image, lower = .8, upper = 1.2)
    if p_pixel_3 >= .4:
        image = tf.image.random_brightness(image, max_delta = .1)
        
    return image

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1./255,
                                                          samplewise_center = True,
                                                          samplewise_std_normalization = True,
                                                          validation_split = 0.2,
                                                          preprocessing_function = data_augment)

train_gen = datagen.flow_from_dataframe(dataframe = DF_TRAIN,
                                        directory = TRAIN_PATH,
                                        x_col = 'image_id',
                                        y_col = 'label',
                                        subset = 'training',
                                        batch_size = BATCH_SIZE,
                                        seed = 1,
                                        color_mode = 'rgb',
                                        shuffle = True,
                                        class_mode = 'categorical',
                                        target_size = (IMAGE_SIZE, IMAGE_SIZE))

valid_gen = datagen.flow_from_dataframe(dataframe = DF_TRAIN,
                                        directory = TRAIN_PATH,
                                        x_col = 'image_id',
                                        y_col = 'label',
                                        subset = 'validation',
                                        batch_size = BATCH_SIZE,
                                        seed = 1,
                                        color_mode = 'rgb',
                                        shuffle = False,
                                        class_mode = 'categorical',
                                        target_size = (IMAGE_SIZE, IMAGE_SIZE))

test_gen = datagen.flow_from_dataframe(dataframe = DF_TEST,
                                       x_col = 'image_path',
                                       y_col = None,
                                       batch_size = BATCH_SIZE,
                                       seed = 1,
                                       color_mode = 'rgb',
                                       shuffle = False,
                                       class_mode = None,
                                       target_size = (IMAGE_SIZE, IMAGE_SIZE))
# Out:
# Found 17118 validated image filenames belonging to 5 classes.
# Found 4279 validated image filenames belonging to 5 classes.
# Found 1 validated image filenames.

# %%
images = [train_gen[0][0][i] for i in range(16)]
fig, axes = plt.subplots(3, 5, figsize = (10, 10))

axes = axes.flatten()

for img, ax in zip(images, axes):
    ax.imshow(img.reshape(IMAGE_SIZE, IMAGE_SIZE, 3))
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# !pip install --quiet vit-keras

from vit_keras import vit
